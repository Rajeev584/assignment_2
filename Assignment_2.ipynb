# %%
Q1: #accepts marks from student and return their respective grade
marks=int(input())
if marks>90:
    print('A')
elif(marks>80 and marks<=90):
    print('B')
elif(marks>=60 and marks<=80):
    print('C')
elif(marks<60):
    print('D')
Q2:# accept cost price and return its taxes
cost=int(input())
if cost>100000:
    print((15/100)*cost)
elif(cost>50000 and cost<=100000):
    print((10/100)*cost)
elif(cost<50000):
    print((5/100)*cost)
Q3:# accept a city from user and display monuments of that city
city=input()
if city=='Delhi':
    print('Red Fort')
elif(city=='Agra'):
    print('Taj Mahal')
elif(city=='Jaipur'):
    print('Jai Mahal')
Q4:# we have to find remaindr basically
n=int(input())
count=0
if n%m==10 or n%m<10:
    count+=1
print(count)

Q5 while loop is used to run a block code until a certain condition met .while loop
evalutes the condition .if the condtion evalutes to True,the code inside the while loop gets executed.
the syntx of the while loop is
while condition:
    # body of while loop
# progam to display numbers from 1 to 10
# intailize the variable
i=1
n=10
while(i<=n):
    print(i)
    i+=1
    
Q6:# USE NESTED WHILE LOOP TO PRINT PATTERN
i=1
while(i<=5):
    j=1
    while(j<=1):
        print(j,end=' ')
        j=j+1
    print(' ')
    i+=1
# print pattern of asterisk
n=int(input())
i=1
while(i<=n):
  j=i+1
  while(j<=n):
    print(i*'*')
    j+=1
  i+=1

# printing traingle of zeroes
n=int(input())
i=1
while(i<=n):
  j=1
  while(j<=i+1):
    print('0',end='')
    j+=1
  i+=1
  print()
  
Q7:# revsersing while loop to print numbers from 1 to 10
i=10
while(i>0):
  print(i)
  i=i-1

Q8: reverse a while loop to print numbers from 10 to 1
i=10
while(i>0):
  print(i)
  i=i-1
# Out:
#   Cell In [7], line 1
#     Q1: #accepts marks from student and return their respective grade
#         ^
# SyntaxError: invalid syntax
